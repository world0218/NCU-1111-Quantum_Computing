# %%
from qiskit import QuantumCircuit
print("This is a quantum circuit of 5 qubits and 5 bits：")
qc = QuantumCircuit(5,5)
qc.measure([0,1,2,3,4], [4,3,2,1,0])
qc.draw('mpl')
# Out:
# This is a quantum circuit of 5 qubits and 5 bits：
